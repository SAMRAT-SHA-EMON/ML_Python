# %% [markdown]
# # Data_Input

# %%
import pandas as pd
data1 = pd.read_excel('1.xlsx')
data2 = pd.read_excel('2.xlsx')

# %%
data1
# Out:
#                           描述       位置信息  区域  \
# 0         嘉裕第六洲龙泽台 4室2厅 280万  嘉裕第六洲龙泽台   崇州
# 1         满2年 中间楼层 套三双卫 随时看房    西蜀御景二期   崇州
# 2           前后中庭 中间楼层 清水房 套三    西蜀御景二期   崇州
# 3         嘉裕第六洲龙泽台 3室2厅 120万  嘉裕第六洲龙泽台   崇州
# 4       嘉裕龙泽台清水套三 户型方正 对小区中庭  嘉裕第六洲龙泽台   崇州
# ..                       ...        ...  ..
# 208    房子是联排端头别墅，小区环境安静，安全性高     嘉裕第六洲   崇州
# 209  嘉裕第六洲 联排别墅  拎包入住 随时可以看房     嘉裕第六洲   崇州
# 210       嘉裕第六洲独栋别墅诚心出售，产权在手     嘉裕第六洲   崇州
# 211       嘉裕第六洲龙泽台 4室2厅 180万  嘉裕第六洲龙泽台   崇州
# 212  嘉裕第六洲清水联排 户型方正 南北通透 满两年     嘉裕第六洲   崇州
#
#                                                   房屋信息             关注信息    总价  \
# 0          4室2厅 | 223.73平米 | 南 | 毛坯 | 低楼层(共9层)  | 暂无数据   0人关注 / 31天以前发布  280万
# 1    3室2厅 | 128.7平米 | 东南 | 毛坯 | 中楼层(共18层) | 2012年建 ...    15人关注 / 一年前发布   77万
# 2           3室2厅 | 128.7平米 | 东南 | 毛坯 | 高楼层(共18层)  | 塔楼   1人关注 / 8个月以前发布   90万
# 3           3室2厅 | 106.8平米 | 南 | 其他 | 低楼层(共7层)  | 暂无数据   0人关注 / 15天以前发布  120万
# ...

# %%
data1.房屋信息
# Out:
# 0            4室2厅 | 223.73平米 | 南 | 毛坯 | 低楼层(共9层)  | 暂无数据
# 1      3室2厅 | 128.7平米 | 东南 | 毛坯 | 中楼层(共18层) | 2012年建 ...
# 2             3室2厅 | 128.7平米 | 东南 | 毛坯 | 高楼层(共18层)  | 塔楼
# 3             3室2厅 | 106.8平米 | 南 | 其他 | 低楼层(共7层)  | 暂无数据
# 4                3室2厅 | 125平米 | 东南 | 毛坯 | 中楼层(共7层)  | 板楼
#                              ...
# 208       5室2厅 | 225平米 | 南 | 毛坯 | 低楼层(共1层) | 2015年建 | 板楼
# 209           5室2厅 | 177.95平米 | 东南 | 简装 | 低楼层(共2层)  | 板楼
# 210            5室3厅 | 242.21平米 | 南 | 其他 | 低楼层(共1层)  | 板楼
# 211           4室2厅 | 208.18平米 | 东南 | 其他 | 低楼层(共9层)  | 板楼
# 212       4室2厅 | 185.4平米 | 南 北 | 毛坯 | 3层  | 暂无数据 | 联排别墅
# Name: 房屋信息, Length: 213, dtype: object

# %%
import re
data1.总价
# Out:
# 0      280万
# 1       77万
# 2       90万
# 3      120万
# 4       89万
#        ...
# 208    380万
# 209    260万
# 210    420万
# 211    180万
# 212    310万
# Name: 总价, Length: 213, dtype: object

# %%
import re
data1.总价.map(lambda x: re.sub("[\u4e00-\u9fa5]",'',x)) #chinese word to other re.sub
# Out:
# 0      280
# 1       77
# 2       90
# 3      120
# 4       89
#       ...
# 208    380
# 209    260
# 210    420
# 211    180
# 212    310
# Name: 总价, Length: 213, dtype: object

# %%
import re 
data1.单价
# Out:
# 0      单价12516元/平米
# 1       单价5983元/平米
# 2       单价6994元/平米
# 3      单价11236元/平米
# 4       单价7120元/平米
#           ...
# 208    单价16889元/平米
# 209    单价14611元/平米
# 210    单价17341元/平米
# 211     单价8647元/平米
# 212    单价16721元/平米
# Name: 单价, Length: 213, dtype: object

# %%
import re
data1.单价=data1.单价.map(lambda x: re.sub("[\u4e00-\u9fa5]",'',x))
data1.单价=data1.单价.map(lambda x: re.sub("/",'',x))
data1.单价=data1.单价.map(lambda x: float(x))
data1.单价
# Out:
# 0      12516.0
# 1       5983.0
# 2       6994.0
# 3      11236.0
# 4       7120.0
#         ...
# 208    16889.0
# 209    14611.0
# 210    17341.0
# 211     8647.0
# 212    16721.0
# Name: 单价, Length: 213, dtype: float64

# %%
import re 
data1.房屋信息
# Out:
# 0            4室2厅 | 223.73平米 | 南 | 毛坯 | 低楼层(共9层)  | 暂无数据
# 1      3室2厅 | 128.7平米 | 东南 | 毛坯 | 中楼层(共18层) | 2012年建 ...
# 2             3室2厅 | 128.7平米 | 东南 | 毛坯 | 高楼层(共18层)  | 塔楼
# 3             3室2厅 | 106.8平米 | 南 | 其他 | 低楼层(共7层)  | 暂无数据
# 4                3室2厅 | 125平米 | 东南 | 毛坯 | 中楼层(共7层)  | 板楼
#                              ...
# 208       5室2厅 | 225平米 | 南 | 毛坯 | 低楼层(共1层) | 2015年建 | 板楼
# 209           5室2厅 | 177.95平米 | 东南 | 简装 | 低楼层(共2层)  | 板楼
# 210            5室3厅 | 242.21平米 | 南 | 其他 | 低楼层(共1层)  | 板楼
# 211           4室2厅 | 208.18平米 | 东南 | 其他 | 低楼层(共9层)  | 板楼
# 212       4室2厅 | 185.4平米 | 南 北 | 毛坯 | 3层  | 暂无数据 | 联排别墅
# Name: 房屋信息, Length: 213, dtype: object

# %%
msg= data1.房屋信息.map(lambda x: len(x.split('|')))
msg.value_counts()
# Out:
# 房屋信息
# 6    138
# 7     67
# 8      8
# Name: count, dtype: int64

# %%
data2=data1[msg==6]
data2['type'] = data2.房屋信息.map(lambda x: x.split('|')[0])
data2['area'] = data2.房屋信息.map(lambda x: x.split('|')[1])
data2['direction'] = data2.房屋信息.map(lambda x: x.split('|')[2])
data2['decoration'] = data2.房屋信息.map(lambda x: x.split('|')[3])
data2['floor'] = data2.房屋信息.map(lambda x: x.split('|')[4])
data2['other'] = data2.房屋信息.map(lambda x: x.split('|')[5])
# Out:
# C:\Users\MONIRUL ISLAM\AppData\Local\Temp\ipykernel_3144\81899955.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['type'] = data2.房屋信息.map(lambda x: x.split('|')[0])
# C:\Users\MONIRUL ISLAM\AppData\Local\Temp\ipykernel_3144\81899955.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['area'] = data2.房屋信息.map(lambda x: x.split('|')[1])
# C:\Users\MONIRUL ISLAM\AppData\Local\Temp\ipykernel_3144\81899955.py:4: SettingWithCopyWarning:
# ...

# %%
data2
# Out:
#                           描述       位置信息  区域  \
# 0         嘉裕第六洲龙泽台 4室2厅 280万  嘉裕第六洲龙泽台   崇州
# 2           前后中庭 中间楼层 清水房 套三    西蜀御景二期   崇州
# 3         嘉裕第六洲龙泽台 3室2厅 120万  嘉裕第六洲龙泽台   崇州
# 4       嘉裕龙泽台清水套三 户型方正 对小区中庭  嘉裕第六洲龙泽台   崇州
# 5         嘉裕第六洲龙泽台 4室2厅 220万  嘉裕第六洲龙泽台   崇州
# ..                       ...        ...  ..
# 205       嘉裕第六洲龙泽台 4室2厅 199万  嘉裕第六洲龙泽台   崇州
# 207       嘉裕第六洲龙泽台 3室2厅 106万  嘉裕第六洲龙泽台   崇州
# 209  嘉裕第六洲 联排别墅  拎包入住 随时可以看房     嘉裕第六洲   崇州
# 210       嘉裕第六洲独栋别墅诚心出售，产权在手     嘉裕第六洲   崇州
# 211       嘉裕第六洲龙泽台 4室2厅 180万  嘉裕第六洲龙泽台   崇州
#
#                                              房屋信息             关注信息    总价  \
# 0     4室2厅 | 223.73平米 | 南 | 毛坯 | 低楼层(共9层)  | 暂无数据   0人关注 / 31天以前发布  280万
# 2      3室2厅 | 128.7平米 | 东南 | 毛坯 | 高楼层(共18层)  | 塔楼   1人关注 / 8个月以前发布   90万
# 3      3室2厅 | 106.8平米 | 南 | 其他 | 低楼层(共7层)  | 暂无数据   0人关注 / 15天以前发布  120万
# 4         3室2厅 | 125平米 | 东南 | 毛坯 | 中楼层(共7层)  | 板楼   4人关注 / 14天以前发布   89万
# ...

# %%
import re 
data2.floor
# Out:
# 0        低楼层(共9层)
# 2       高楼层(共18层)
# 3        低楼层(共7层)
# 4        中楼层(共7层)
# 5        低楼层(共6层)
#            ...
# 205      低楼层(共9层)
# 207      中楼层(共7层)
# 209      低楼层(共2层)
# 210      低楼层(共1层)
# 211      低楼层(共9层)
# Name: floor, Length: 138, dtype: object

# %%
data2['floorh']= data2.floor.map(lambda x: x.split('(')[0])
data2['floorb']= data2.floor.map(lambda x: x.split('(')[-1])
data2
# Out:
# C:\Users\MONIRUL ISLAM\AppData\Local\Temp\ipykernel_3144\1104784672.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['floorh']= data2.floor.map(lambda x: x.split('(')[0])
# C:\Users\MONIRUL ISLAM\AppData\Local\Temp\ipykernel_3144\1104784672.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2
# 4         3室2厅 | 125平米 | 东南 | 毛坯 | 中楼层(共7层)  | 板楼   4人关注 / 14天以前发布   89万
# ...

# %%
data2.floorb.map(lambda x: re.sub("[\u4e00-\u9fa5]",'',x))
# Out:
# 0       9)
# 2      18)
# 3       7)
# 4       7)
# 5       6)
#        ...
# 205     9)
# 207     7)
# 209     2)
# 210     1)
# 211     9)
# Name: floorb, Length: 138, dtype: object

# %%
data2.floorb=data2.floorb.map(lambda x: x.split(')'))
# Out:
# C:\Users\MONIRUL ISLAM\AppData\Local\Temp\ipykernel_3144\1175621867.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.floorb=data2.floorb.map(lambda x: x.split(')'))

# %%
data2
# Out:
#                           描述       位置信息  区域  \
# 0         嘉裕第六洲龙泽台 4室2厅 280万  嘉裕第六洲龙泽台   崇州
# 2           前后中庭 中间楼层 清水房 套三    西蜀御景二期   崇州
# 3         嘉裕第六洲龙泽台 3室2厅 120万  嘉裕第六洲龙泽台   崇州
# 4       嘉裕龙泽台清水套三 户型方正 对小区中庭  嘉裕第六洲龙泽台   崇州
# 5         嘉裕第六洲龙泽台 4室2厅 220万  嘉裕第六洲龙泽台   崇州
# ..                       ...        ...  ..
# 205       嘉裕第六洲龙泽台 4室2厅 199万  嘉裕第六洲龙泽台   崇州
# 207       嘉裕第六洲龙泽台 3室2厅 106万  嘉裕第六洲龙泽台   崇州
# 209  嘉裕第六洲 联排别墅  拎包入住 随时可以看房     嘉裕第六洲   崇州
# 210       嘉裕第六洲独栋别墅诚心出售，产权在手     嘉裕第六洲   崇州
# 211       嘉裕第六洲龙泽台 4室2厅 180万  嘉裕第六洲龙泽台   崇州
#
#                                              房屋信息             关注信息    总价  \
# 0     4室2厅 | 223.73平米 | 南 | 毛坯 | 低楼层(共9层)  | 暂无数据   0人关注 / 31天以前发布  280万
# 2      3室2厅 | 128.7平米 | 东南 | 毛坯 | 高楼层(共18层)  | 塔楼   1人关注 / 8个月以前发布   90万
# 3      3室2厅 | 106.8平米 | 南 | 其他 | 低楼层(共7层)  | 暂无数据   0人关注 / 15天以前发布  120万
# 4         3室2厅 | 125平米 | 东南 | 毛坯 | 中楼层(共7层)  | 板楼   4人关注 / 14天以前发布   89万
# ...

# %%
data2
# Out:
#                           描述       位置信息  区域  \
# 0         嘉裕第六洲龙泽台 4室2厅 280万  嘉裕第六洲龙泽台   崇州
# 2           前后中庭 中间楼层 清水房 套三    西蜀御景二期   崇州
# 3         嘉裕第六洲龙泽台 3室2厅 120万  嘉裕第六洲龙泽台   崇州
# 4       嘉裕龙泽台清水套三 户型方正 对小区中庭  嘉裕第六洲龙泽台   崇州
# 5         嘉裕第六洲龙泽台 4室2厅 220万  嘉裕第六洲龙泽台   崇州
# ..                       ...        ...  ..
# 205       嘉裕第六洲龙泽台 4室2厅 199万  嘉裕第六洲龙泽台   崇州
# 207       嘉裕第六洲龙泽台 3室2厅 106万  嘉裕第六洲龙泽台   崇州
# 209  嘉裕第六洲 联排别墅  拎包入住 随时可以看房     嘉裕第六洲   崇州
# 210       嘉裕第六洲独栋别墅诚心出售，产权在手     嘉裕第六洲   崇州
# 211       嘉裕第六洲龙泽台 4室2厅 180万  嘉裕第六洲龙泽台   崇州
#
#                                              房屋信息             关注信息    总价  \
# 0     4室2厅 | 223.73平米 | 南 | 毛坯 | 低楼层(共9层)  | 暂无数据   0人关注 / 31天以前发布  280万
# 2      3室2厅 | 128.7平米 | 东南 | 毛坯 | 高楼层(共18层)  | 塔楼   1人关注 / 8个月以前发布   90万
# 3      3室2厅 | 106.8平米 | 南 | 其他 | 低楼层(共7层)  | 暂无数据   0人关注 / 15天以前发布  120万
# 4         3室2厅 | 125平米 | 东南 | 毛坯 | 中楼层(共7层)  | 板楼   4人关注 / 14天以前发布   89万
# ...

# %%
data2.floorb = data2.floorb.map(lambda x: re.sub("[\u4e00-\u9fa5]",'',x))
data2.floorb = data2.floorb.map(lambda x: re.sub("\)",'',x))
# Out:
# C:\Users\MONIRUL ISLAM\AppData\Local\Temp\ipykernel_3144\4254427858.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.floorb = data2.floorb.map(lambda x: re.sub("[\u4e00-\u9fa5]",'',x))
# C:\Users\MONIRUL ISLAM\AppData\Local\Temp\ipykernel_3144\4254427858.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.floorb = data2.floorb.map(lambda x: re.sub("\)",'',x))

# %%
data2
# Out:
#                           描述       位置信息  区域  \
# 0         嘉裕第六洲龙泽台 4室2厅 280万  嘉裕第六洲龙泽台   崇州
# 2           前后中庭 中间楼层 清水房 套三    西蜀御景二期   崇州
# 3         嘉裕第六洲龙泽台 3室2厅 120万  嘉裕第六洲龙泽台   崇州
# 4       嘉裕龙泽台清水套三 户型方正 对小区中庭  嘉裕第六洲龙泽台   崇州
# 5         嘉裕第六洲龙泽台 4室2厅 220万  嘉裕第六洲龙泽台   崇州
# ..                       ...        ...  ..
# 205       嘉裕第六洲龙泽台 4室2厅 199万  嘉裕第六洲龙泽台   崇州
# 207       嘉裕第六洲龙泽台 3室2厅 106万  嘉裕第六洲龙泽台   崇州
# 209  嘉裕第六洲 联排别墅  拎包入住 随时可以看房     嘉裕第六洲   崇州
# 210       嘉裕第六洲独栋别墅诚心出售，产权在手     嘉裕第六洲   崇州
# 211       嘉裕第六洲龙泽台 4室2厅 180万  嘉裕第六洲龙泽台   崇州
#
#                                              房屋信息             关注信息    总价  \
# 0     4室2厅 | 223.73平米 | 南 | 毛坯 | 低楼层(共9层)  | 暂无数据   0人关注 / 31天以前发布  280万
# 2      3室2厅 | 128.7平米 | 东南 | 毛坯 | 高楼层(共18层)  | 塔楼   1人关注 / 8个月以前发布   90万
# 3      3室2厅 | 106.8平米 | 南 | 其他 | 低楼层(共7层)  | 暂无数据   0人关注 / 15天以前发布  120万
# 4         3室2厅 | 125平米 | 东南 | 毛坯 | 中楼层(共7层)  | 板楼   4人关注 / 14天以前发布   89万
# ...
