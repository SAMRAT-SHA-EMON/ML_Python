# %%
# import python libraries

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
# import csv file
df = pd.read_csv('Sales_Data.csv', encoding= 'unicode_escape')

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head()
# Out:
#      User_ID Cust_name Product_ID Gender Age Group   Age  Marital_Status  \
# 0  1002903.0   Khadija  P00125942      F     26-35  28.0             0.0
# 1  1000732.0     Deeya  P00110942      F     26-35  35.0             1.0
# 2  1001990.0      Rimi  P00118542      F     26-35  35.0             1.0
# 3  1001425.0   Shishir  P00237842      M      0-17  16.0             0.0
# 4  1000588.0      Joni  P00057942      M     26-35  28.0             1.0
#
#         State      Zone       Occupation Product_Category  Orders   Amount  \
# 0       Dhaka   Western       Healthcare             Auto     1.0  23952.0
# 1      Khulna  Southern             Govt             Auto     3.0  23934.0
# 2     Borisal   Central       Automobile             Auto     3.0  23924.0
# 3  Chottogram  Southern     Construction             Auto     2.0  23912.0
# 4      Sylhet   Western  Food Processing             Auto     2.0  23877.0
#
#    Status  unnamed1
# 0     NaN       NaN
# 1     NaN       NaN
# 2     NaN       NaN
# 3     NaN       NaN
# 4     NaN       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           9036 non-null   float64
#  1   Cust_name         9036 non-null   object
#  2   Product_ID        9036 non-null   object
#  3   Gender            9036 non-null   object
#  4   Age Group         9036 non-null   object
#  5   Age               9036 non-null   float64
#  6   Marital_Status    9036 non-null   float64
#  7   State             9036 non-null   object
#  8   Zone              9036 non-null   object
#  9   Occupation        9036 non-null   object
#  10  Product_Category  9036 non-null   object
#  11  Orders            9036 non-null   float64
#  12  Amount            9024 non-null   float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(7), object(8)
# memory usage: 1.3+ MB

# %%
#drop unrelated/blank columns
df.drop(['Status', 'unnamed1'], axis=1, inplace=True)

# %%
#check for null values
pd.isnull(df).sum()
# Out:
# User_ID             2215
# Cust_name           2215
# Product_ID          2215
# Gender              2215
# Age Group           2215
# Age                 2215
# Marital_Status      2215
# State               2215
# Zone                2215
# Occupation          2215
# Product_Category    2215
# Orders              2215
# Amount              2227
# dtype: int64

# %%
# drop null values
df.dropna(inplace=True)

# %%
# change data type
df['Amount'] = df['Amount'].astype('int')

# %%
df['Amount'].dtypes
# Out:
# dtype('int32')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#rename column
df.rename(columns= {'Marital_Status':'Shaadi'})
# Out:
#          User_ID  Cust_name Product_ID Gender Age Group   Age  Shaadi  \
# 0      1002903.0    Khadija  P00125942      F     26-35  28.0     0.0
# 1      1000732.0      Deeya  P00110942      F     26-35  35.0     1.0
# 2      1001990.0       Rimi  P00118542      F     26-35  35.0     1.0
# 3      1001425.0    Shishir  P00237842      M      0-17  16.0     0.0
# 4      1000588.0       Joni  P00057942      M     26-35  28.0     1.0
# ...          ...        ...        ...    ...       ...   ...     ...
# 11245  1004140.0  Bertelson  P00057442      F     26-35  31.0     1.0
# 11246  1000695.0    Manning  P00296942      M     18-25  19.0     1.0
# 11248  1001209.0      Oshin  P00201342      F     36-45  40.0     0.0
# 11249  1004023.0     Noonan  P00059442      M     36-45  37.0     0.0
# 11250  1002744.0    Brumley  P00281742      F     18-25  19.0     0.0
#
#             State      Zone       Occupation Product_Category  Orders  Amount
# 0           Dhaka   Western       Healthcare             Auto     1.0   23952
# 1          Khulna  Southern             Govt             Auto     3.0   23934
# 2         Borisal   Central       Automobile             Auto     3.0   23924
# 3      Chottogram  Southern     Construction             Auto     2.0   23912
# 4          Sylhet   Western  Food Processing             Auto     2.0   23877
# ...           ...       ...              ...              ...     ...     ...
# 11245    Rajshahi   Central         Aviation           Office     2.0     381
# 11246       Dhaka   Western         Chemical           Office     4.0     370
# 11248     Rangpur   Central          Textile           Office     4.0     213
# 11249  Chottogram  Southern      Agriculture           Office     3.0     206
# 11250       Dhaka   Western       Healthcare           Office     3.0     188
#
# [9024 rows x 13 columns]

# %%
# describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc)
df.describe()
# Out:
#             User_ID          Age  Marital_Status      Orders        Amount
# count  9.024000e+03  9024.000000     9024.000000  9024.00000   9024.000000
# mean   1.003012e+06    35.424424        0.420988     2.49191   9641.407691
# std    1.712431e+03    12.675537        0.493745     1.11499   5339.958268
# min    1.000001e+06    12.000000        0.000000     1.00000    188.000000
# 25%    1.001502e+06    27.000000        0.000000     2.00000   5435.000000
# 50%    1.003074e+06    33.000000        0.000000     2.00000   8262.000000
# 75%    1.004431e+06    43.000000        1.000000     3.00000  13056.500000
# max    1.006040e+06    92.000000        1.000000     4.00000  23952.000000

# %%
# use describe() for specific columns
df[['Age', 'Orders', 'Amount']].describe()
# Out:
#                Age      Orders        Amount
# count  9024.000000  9024.00000   9024.000000
# mean     35.424424     2.49191   9641.407691
# std      12.675537     1.11499   5339.958268
# min      12.000000     1.00000    188.000000
# 25%      27.000000     2.00000   5435.000000
# 50%      33.000000     2.00000   8262.000000
# 75%      43.000000     3.00000  13056.500000
# max      92.000000     4.00000  23952.000000

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Gender

# %%
# plotting a bar chart for Gender and it's count

ax = sns.countplot(x = 'Gender',data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plotting a bar chart for gender vs total amount

sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Gender',y= 'Amount' ,data = sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are females and even the purchasing power of females are greater than men*

# %% [markdown]
# ### Age

# %%
ax = sns.countplot(data = df, x = 'Age Group', hue = 'Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Total Amount vs Age Group
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Age Group',y= 'Amount' ,data = sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are of age group between 26-35 yrs female*

# %% [markdown]
# ### State

# %%
# total number of orders from top 10 states

sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Orders')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
# total amount/sales from top 10 states

sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Amount')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively*

# %% [markdown]
# ### Marital Status

# %%
ax = sns.countplot(data = df, x = 'Marital_Status')

sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data = sales_state, x = 'Marital_Status',y= 'Amount', hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are married (women) and they have high purchasing power*

# %% [markdown]
# ### Occupation

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Occupation')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector*

# %% [markdown]
# ### Product Category

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Product_Category')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the sold products are from Food, Clothing and Electronics category*

# %%
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %%
# top 10 most sold products (same thing as above)

fig1, ax1 = plt.subplots(figsize=(12,7))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# ## Conclusion:
#
# ###

# %% [markdown]
# *Married women age group 26-35 yrs from UP,  Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Food, Clothing and Electronics category*

# %% [markdown]
# complete project on YouTube: https://www.youtube.com/@RishabhMishraOfficial
#
# complete project on GitHub: https://github.com/rishabhnmishra/Python_Diwali_Sales_Analysis

# %% [markdown]
# Thank you!
